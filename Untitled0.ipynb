# %% [markdown]
# ---
#
#
# #Заливка данных
#
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/german-credit.csv')

# %%
df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  default
# ...

# %% [markdown]
# ---
#
# #Предобработка
#
#
# ---

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  default
# 0         6             radio/TV        0
# 1        48             radio/TV        1
# 2        12            education        0
# 3        42  furniture/equipment        0
# 4        24                  car        1

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
df.isna().mean()
# Out:
# age                 0.000
# sex                 0.000
# job                 0.000
# housing             0.000
# saving_accounts     0.183
# checking_account    0.394
# credit_amount       0.000
# duration            0.000
# purpose             0.000
# default             0.000
# dtype: float64

# %% [markdown]
# ---
#
# #Анализ
#
#
# ---

# %%
df['checking_account'] = df['checking_account'].fillna('no_info')

# %%
t = df.groupby(['checking_account','sex'])[['credit_amount','default']].agg({'credit_amount':['count', 'mean', 'median'],
                                                                      'default':['mean']})

# %%
t
# Out:
#                         credit_amount                        default
#                                 count         mean  median      mean
# checking_account sex
# little           female            88  2564.215909  1838.5  0.522727
#                  male             186  3464.295699  2589.5  0.478495
# moderate         female            86  3720.034884  2651.0  0.476744
#                  male             183  3878.092896  2520.0  0.349727
# no_info          female           116  2708.750000  1935.0  0.155172
#                  male             278  3310.169065  2393.5  0.100719
# rich             female            20  1616.050000  1400.5  0.200000
#                  male              43  2438.860465  1925.0  0.232558

# %%
df.pivot_table(index='checking_account',
               columns = 'sex', 
               values=['credit_amount','duration'], 
               aggfunc={'credit_amount':['count','mean','median'],
                        'duration':['mean']})
# Out:
#                  credit_amount                                           \
#                          count                mean               median
# sex                     female   male       female         male  female
# checking_account
# little                    88.0  186.0  2564.215909  3464.295699  1838.5
# moderate                  86.0  183.0  3720.034884  3878.092896  2651.0
# no_info                  116.0  278.0  2708.750000  3310.169065  1935.0
# rich                      20.0   43.0  1616.050000  2438.860465  1400.5
#
#                            duration
#                                mean
# sex                 male     female       male
# checking_account
# little            2589.5  19.693182  22.118280
# moderate          2520.0  21.848837  23.071038
# no_info           2393.5  18.362069  20.618705
# rich              1925.0  14.200000  18.813953

# %%
df.pivot_table(index='checking_account',
               columns = 'sex', 
               values=['credit_amount','duration'], 
               aggfunc=['count','mean'],
               margins=True)
# Out:
#                          count                                         mean  \
#                  credit_amount            duration            credit_amount
# sex                     female male   All   female male   All        female
# checking_account
# little                      88  186   274       88  186   274   2564.215909
# moderate                    86  183   269       86  183   269   3720.034884
# no_info                    116  278   394      116  278   394   2708.750000
# rich                        20   43    63       20   43    63   1616.050000
# All                        310  690  1000      310  690  1000   2877.774194
#
#
#                                              duration
# sex                      male          All     female       male        All
# checking_account
# little            3464.295699  3175.218978  19.693182  22.118280  21.339416
# moderate          3878.092896  3827.561338  21.848837  23.071038  22.680297
# ...

# %%
t = df.pivot_table(index='checking_account',
               columns = 'sex', 
               values=['credit_amount','duration'], 
               aggfunc=['count','mean'],
               margins=True)

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#                   count_credit_amount_female  count_credit_amount_male  \
# checking_account
# little                                    88                       186
# moderate                                  86                       183
# no_info                                  116                       278
# rich                                      20                        43
# All                                      310                       690
#
#                   count_credit_amount_All  count_duration_female  \
# checking_account
# little                                274                     88
# moderate                              269                     86
# no_info                               394                    116
# rich                                   63                     20
# All                                  1000                    310
#
#                   count_duration_male  count_duration_All  \
# checking_account
# ...

# %%
df.groupby('checking_account')['credit_amount'].agg(['count','mean','median'])
# Out:
#                   count         mean  median
# checking_account
# little              274  3175.218978  2353.5
# moderate            269  3827.561338  2622.0
# no_info             394  3133.101523  2248.0
# rich                 63  2177.650794  1881.0

# %% [markdown]
# Самый низкий credit_amount в категории rich

# %%
df.groupby('housing')['credit_amount'].agg(['count','mean','median'])
# Out:
#          count         mean  median
# housing
# free       108  4906.212963  3800.5
# own        713  3060.939691  2238.0
# rent       179  3122.553073  2301.0

# %% [markdown]
# Вывод

# %%
df.groupby('credit_amount')['default'].agg(['count','mean'])
# Out:
#                count  mean
# credit_amount
# 250                1   0.0
# 276                1   0.0
# 338                1   0.0
# 339                1   0.0
# 343                1   0.0
# ...              ...   ...
# 15653              1   0.0
# 15672              1   1.0
# 15857              1   0.0
# 15945              1   1.0
# 18424              1   1.0
#
# [921 rows x 2 columns]

# %%
df['credit_amount_group'] = pd.cut(df['credit_amount'], 5)

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little          no_info           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    duration              purpose  default credit_amount_group
# 0         6             radio/TV        0   (231.826, 3884.8]
# 1        48             radio/TV        1    (3884.8, 7519.6]
# 2        12            education        0   (231.826, 3884.8]
# 3        42  furniture/equipment        0   (7519.6, 11154.4]
# 4        24                  car        1    (3884.8, 7519.6]

# %%
df.groupby('credit_amount_group')['default'].agg(['count','mean'])
# Out:
#                      count      mean
# credit_amount_group
# (231.826, 3884.8]      738  0.256098
# (3884.8, 7519.6]       177  0.384181
# (7519.6, 11154.4]       57  0.403509
# (11154.4, 14789.2]      22  0.727273
# (14789.2, 18424.0]       6  0.666667

# %%
df['credit_amount_group_2'] = pd.qcut(df['credit_amount'], 5)

# %%
df.groupby('credit_amount_group_2')['default'].agg(['count','mean'])
# Out:
#                        count      mean
# credit_amount_group_2
# (249.999, 1262.0]        201  0.303483
# (1262.0, 1906.8]         199  0.241206
# (1906.8, 2852.4]         200  0.270000
# (2852.4, 4720.0]         200  0.260000
# (4720.0, 18424.0]        200  0.425000

# %%
df['credit_amount_group_3'] = pd.cut(df['credit_amount'], [0, 1000, 2000, 3000, 4000, 5000, np.inf])

# %%
df.groupby('credit_amount_group_3')['default'].agg(['count','mean'])
# Out:
#                        count      mean
# credit_amount_group_3
# (0.0, 1000.0]            116  0.318966
# (1000.0, 2000.0]         316  0.265823
# (2000.0, 3000.0]         188  0.239362
# (3000.0, 4000.0]         134  0.216418
# (4000.0, 5000.0]          58  0.465517
# (5000.0, inf]            188  0.414894

# %%
df['credit_amount_group_4'] = pd.cut(df['credit_amount'], [0, 1000, np.inf], labels=['0-1k', '1k+'])

# %%
df.groupby('credit_amount_group_4')['default'].agg(['count','mean'])
# Out:
#                        count      mean
# credit_amount_group_4
# 0-1k                     116  0.318966
# 1k+                      884  0.297511

# %%
df.groupby('credit_amount_group_2')['default'].agg(['count','mean'])
# Out:
#                        count      mean
# credit_amount_group_2
# (249.999, 1262.0]        201  0.303483
# (1262.0, 1906.8]         199  0.241206
# (1906.8, 2852.4]         200  0.270000
# (2852.4, 4720.0]         200  0.260000
# (4720.0, 18424.0]        200  0.425000

# %%
df.groupby('credit_amount_group_2')['default'].mean().plot(rot=45,ylim=0, grid=True, kind='bar')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little          no_info           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    duration              purpose  default credit_amount_group  \
# 0         6             radio/TV        0   (231.826, 3884.8]
# 1        48             radio/TV        1    (3884.8, 7519.6]
# 2        12            education        0   (231.826, 3884.8]
# 3        42  furniture/equipment        0   (7519.6, 11154.4]
# 4        24                  car        1    (3884.8, 7519.6]
#
#   credit_amount_group_2 credit_amount_group_3 credit_amount_group_4
# ...

# %%
df['checking_account'].value_counts()
# Out:
# no_info     394
# little      274
# moderate    269
# rich         63
# Name: checking_account, dtype: int64

# %%
df['checking_account'].value_counts(normalize=True)
# Out:
# no_info     0.394
# little      0.274
# moderate    0.269
# rich        0.063
# Name: checking_account, dtype: float64

# %%
df['default'].value_counts(normalize=True)
# Out:
# 0    0.7
# 1    0.3
# Name: default, dtype: float64

# %%
df['default'].mean()
# Out:
# 0.3

# %%
pd.get_dummies(df['checking_account'])
# Out:
#      little  moderate  no_info  rich
# 0         1         0        0     0
# 1         0         1        0     0
# 2         0         0        1     0
# 3         1         0        0     0
# 4         1         0        0     0
# ..      ...       ...      ...   ...
# 995       0         0        1     0
# 996       1         0        0     0
# 997       0         0        1     0
# 998       1         0        0     0
# 999       0         1        0     0
#
# [1000 rows x 4 columns]

# %%
df['credit_amount'].hist()

# %%
df['credit_amount'].mean()
# Out:
# 3271.258

# %%
t = pd.DataFrame({'salary':[20, 30 , 40 , 50, 400000000]})

# %%
t['salary'].mean()
# Out:
# 80000028.0

# %%
t['salary'].median()
# Out:
# 40.0

# %%
df['credit_amount'].agg(['mean', 'median'])
# Out:
# mean      3271.258
# median    2319.500
# Name: credit_amount, dtype: float64

# %%
df['credit_amount'].hist()

# %%
df.boxplot('credit_amount')

# %%
df.boxplot('credit_amount', by='checking_account')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df['credit_amount'].describe()
# Out:
# count     1000.000000
# mean      3271.258000
# std       2822.736876
# min        250.000000
# 25%       1365.500000
# 50%       2319.500000
# 75%       3972.250000
# max      18424.000000
# Name: credit_amount, dtype: float64

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little          no_info           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    duration              purpose  default credit_amount_group  \
# 0         6             radio/TV        0   (231.826, 3884.8]
# 1        48             radio/TV        1    (3884.8, 7519.6]
# 2        12            education        0   (231.826, 3884.8]
# 3        42  furniture/equipment        0   (7519.6, 11154.4]
# 4        24                  car        1    (3884.8, 7519.6]
#
#   credit_amount_group_2 credit_amount_group_3 credit_amount_group_4
# ...

# %%
df.plot(x='age', y='credit_amount', kind='scatter', figsize=(10,5), alpha=0.3)

# %%
df['age_group'] = pd.cut(df['age'], 5)

# %%
df.groupby('age_group')['credit_amount'].agg(['count','mean','median'])
# Out:
#                 count         mean  median
# age_group
# (18.944, 30.2]    411  3174.428224  2221.0
# (30.2, 41.4]      332  3270.783133  2401.5
# (41.4, 52.6]      161  3423.515528  2348.0
# (52.6, 63.8]       68  3616.264706  2128.5
# (63.8, 75.0]       28  2984.857143  1503.0

# %%
df.groupby('age_group')['credit_amount'].median().plot(ylim=0, grid=True)

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little          no_info           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    duration              purpose  default credit_amount_group  \
# 0         6             radio/TV        0   (231.826, 3884.8]
# 1        48             radio/TV        1    (3884.8, 7519.6]
# 2        12            education        0   (231.826, 3884.8]
# 3        42  furniture/equipment        0   (7519.6, 11154.4]
# 4        24                  car        1    (3884.8, 7519.6]
#
#   credit_amount_group_2 credit_amount_group_3 credit_amount_group_4  \
# ...

# %%
df[['age', 'credit_amount']].corr()
# Out:
#                     age  credit_amount
# age            1.000000       0.032716
# credit_amount  0.032716       1.000000
